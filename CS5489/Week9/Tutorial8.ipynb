# %% [markdown]
# **Name:** Xian Jia Le ,Ben
#
# **EID:** 56214537

# %% [markdown]
# # CS5489 - Tutorial 8
# ## Face Detection with MLPs
#
# In this tutorial you will train an MLP to detect whether there is a face in a small image patch.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import matplotlib_inline   # setup output image format
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
import os
import zipfile
import fnmatch
random.seed(100)
import skimage.io
import skimage.color
import skimage.transform
from scipy import ndimage

# %% [markdown]
# Next we will load keras and tensorflow.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
import struct
K.set_image_data_format('channels_last')

# %%
import sys
#print("Python:", sys.version, "Keras:", keras.__version__, "TF:", tf.__version__)
print("Python:", sys.version, "TF:", tf.__version__)
# Out:
# Python: 3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)] TF: 2.10.0

# %% [markdown]
# ##  Loading Data and Pre-processing
# Next we need to load the images.  Download `faces.zip`, and place it in the same directory as this ipynb file.  **Do not unzip it.** Then run the following cell to load the images.

# %%
imgdata = {'train':[], 'test':[]}
classes = {'train':[], 'test':[]}

# the dataset is too big, so subsample the training and test sets...
# reduce training set by a factor of 4
train_subsample = 1
train_counter = [0, 0]
# maximum number of samples in each class for test set
test_maxsample = 472
test_counter = [0, 0]

# load the zip file
filename = 'faces.zip'
zfile = zipfile.ZipFile(filename, 'r')

for name in zfile.namelist():
    # check file name matches
    if fnmatch.fnmatch(name, "faces/*/*/*.png"):
        
        # filename is : faces/train/face/fname.png
        (fdir1, fname)  = os.path.split(name)     # get file name
        (fdir2, fclass) = os.path.split(fdir1) # get class (face, nonface)
        (fdir3, fset)   = os.path.split(fdir2) # get training/test set
        # class 1 = face; class 0 = non-face
        myclass = int(fclass == "face")  

        loadme = False
        if fset == 'train':
            if (train_counter[myclass] % train_subsample) == 0:
                loadme = True
            train_counter[myclass] += 1
        elif fset == 'test':
            if test_counter[myclass] < test_maxsample:
                loadme = True
            test_counter[myclass] += 1
            
        if (loadme):
            # open file in memory, and parse as an image
            myfile = zfile.open(name)
            #img = matplotlib.image.imread(myfile)
            img = skimage.io.imread(myfile, as_gray=True)
            myfile.close()
            
            # append data
            imgdata[fset].append(img)
            classes[fset].append(myclass)

        
zfile.close()
imgsize = img.shape

print(len(imgdata['train']))
print(len(imgdata['test']))
trainclass2start = sum(classes['train'])
# Out:
# 6977
# 944

# %% [markdown]
# Next we will convert the list of images into a block (array) of images for easier processing.

# %%
# convert list to numpy array
trainY = asarray(classes['train'])
testY  = asarray(classes['test'])
print(trainY[:5])

# convert class labels to binary indicators
trainYb = keras.utils.to_categorical(trainY)
testYb  = keras.utils.to_categorical(testY)
print(f"trainYb {trainYb.shape} testYb {testYb.shape}")

# convert list of ndarray to ndarray
trainI = asarray(imgdata['train']).reshape((6977,19,19,1))
testI  = asarray(imgdata['test']).reshape((944,19,19,1))

# cleanup memory
del imgdata

# shuffle the data (since it is in order by class)
random.seed(123)
inds1 = random.permutation(len(trainI)).tolist()
inds2 = random.permutation(len(testI)).tolist()
trainYb = trainYb[inds1]
testYb  = testYb[inds2]
trainY = trainY[inds1]
testY  = testY[inds2]
trainI = trainI[inds1]
testI = testI[inds2]

print(trainI.shape)
print(testI.shape)
# Out:
# [1 1 1 1 1]
# trainYb (6977, 2) testYb (944, 2)
# (6977, 19, 19, 1)
# (944, 19, 19, 1)

# %% [markdown]
# Each image is a 19x19x1 array of pixel values.  The last dimension is the number of channels in the image - in this case the image is grayscale, so there is only 1 channel.  Run the below code to show an example:

# %%
print(img.shape)
plt.subplot(1,2,1)
plt.imshow(squeeze(trainI[1]), cmap='gray', interpolation='nearest')
plt.title("face sample")
plt.subplot(1,2,2)
plt.imshow(squeeze(trainI[2]), cmap='gray', interpolation='nearest')
plt.title("non-face sample")
plt.show()
# Out:
# (19, 19)

# %% [markdown]
# Run the below code to show more images!

# %%
# function to make an image montage
def image_montage(X, imsize=None, maxw=10):
    """X can be a list of images, or a matrix of vectorized images.
      Specify imsize when X is a matrix."""
    tmp = []
    numimgs = len(X)
    
    # create a list of images (reshape if necessary)
    for i in range(0,numimgs):
        if imsize != None:
            tmp.append(X[i].reshape(imsize))
        else:
            tmp.append(squeeze(X[i]))
    
    # add blanks
    if (numimgs > maxw) and (mod(numimgs, maxw) > 0):
        leftover = maxw - mod(numimgs, maxw)
        meanimg = 0.5*(X[0].max()+X[0].min())
        for i in range(0,leftover):
            tmp.append(ones(tmp[0].shape)*meanimg)
    
    # make the montage
    tmp2 = []
    for i in range(0,len(tmp),maxw):
        tmp2.append( hstack(tmp[i:i+maxw]) )
    montimg = vstack(tmp2) 
    return montimg

# show images in a plot
def show_imgs(W_list, nc=10, highlight_green=None, highlight_red=None, titles=None):
    # nc is the number of columns
    nfilter = len(W_list)
    nr = (nfilter - 1) // nc + 1
    for i in range(nr):
        for j in range(nc):
            idx = i * nc + j
            if idx == nfilter:
                break
            plt.subplot(nr, nc, idx + 1)
            cur_W = W_list[idx]
            plt.imshow(cur_W,cmap='gray', interpolation='nearest')  
            if titles is not None:
                if isinstance(titles, str):
                    plt.title(titles.format(idx))
                else:
                    plt.title(titles[idx])
            
            if ((highlight_green is not None) and highlight_green[idx]) or \
               ((highlight_red is not None) and highlight_red[idx]): 
                ax = plt.gca()
                if highlight_green[idx]:
                    mycol = '#00FF00'
                else:
                    mycol = 'r'
                for S in ['bottom', 'top', 'right', 'left']:
                    ax.spines[S].set_color(mycol)
                    ax.spines[S].set_lw(2.0)
                ax.xaxis.set_ticks_position('none')               
                ax.yaxis.set_ticks_position('none')
                ax.set_xticks([])
                ax.set_yticks([])
            else:
                plt.gca().set_axis_off()

# show a few images
plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,0]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,1]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

# %% [markdown]
# Next we will generate the training/validation set from the training data.

# %%
# generate fixed validation set of 10% of the training set
vtrainI, validI, vtrainYb, validYb = \
  model_selection.train_test_split(trainI, trainYb, 
  train_size=0.9, test_size=0.1, random_state=4488)

# make validation data
validsetI = (validI, validYb)

print(vtrainI.shape)
print(validI.shape)
# Out:
# (6279, 19, 19, 1)
# (698, 19, 19, 1)

# %% [markdown]
# Here are some useful functions.

# %%
def plot_history(history): 
    fig, ax1 = plt.subplots()
    
    ax1.plot(history.history['loss'], 'r', label="training loss ({:.6f})".format(history.history['loss'][-1]))
    ax1.plot(history.history['val_loss'], 'r--', label="validation loss ({:.6f})".format(history.history['val_loss'][-1]))
    ax1.grid(True)
    ax1.set_xlabel('iteration')
    ax1.legend(loc="best", fontsize=9)    
    ax1.set_ylabel('loss', color='r')
    ax1.tick_params('y', colors='r')

    
    if 'accuracy' in history.history:
        ax2 = ax1.twinx()

        ax2.plot(history.history['accuracy'], 'b', label="training acc ({:.4f})".format(history.history['accuracy'][-1]))
        ax2.plot(history.history['val_accuracy'], 'b--', label="validation acc ({:.4f})".format(history.history['val_accuracy'][-1]))

        ax2.legend(loc="best", fontsize=9)
        ax2.set_ylabel('acc', color='b')        
        ax2.tick_params('y', colors='b')

# %% [markdown]
# Now let's try a simple logistic regression classifier, trained using Keras. Since the inputs are images, we will convert the input image into a vector using the "Flatten" layer first.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tf.random.set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_accuracy',      # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(learning_rate=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 9: early stopping
# test accuracy: 0.6059322033898306

# %% [markdown]
# ## Detection using MLP
#
# Train an MLP to classify an image patch as face or not face.  Use  `vtrainI` and `vtrainYb` (or `vtrainY`) as the training set and `validsetI` as the validation set.  You can try different architectures, and adjust values of the learning rates, number of iterations, early stopping to get a good result.  Use a large batch size (e.g., 50) to speed up the training time.  Remember to add the `callbacks` so that you can monitor the training process.

# %%
### INSERT YOUR CODE HERE
K.clear_session()

nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))
nn.add(Dense(units=79,activation="sigmoid"))        # vectorize the input image
nn.add(Dense(units=13,activation="relu"))
nn.add(Dense(units=2, activation='softmax')) 

nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(learning_rate=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )
# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_loss',      # use validation accuracy for stopping
               min_delta=0.005, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]


nn.summary()

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 361)               0
#
#  dense (Dense)               (None, 79)                28598
#
#  dense_1 (Dense)             (None, 13)                1040
#
#  dense_2 (Dense)             (None, 2)                 28
#
# =================================================================
# Total params: 29,666
# Trainable params: 29,666
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 16: early stopping
# test accuracy: 0.6165254237288136

# %% [markdown]
# _How does the MLP compare to the linear and non-linear classifiers that you tried in Tutorial 4?_
#
# In tutorial 4, the result from the classifiers are around 0.5. Based on above result, MLP give 0.6 accuarcy. Therefore, MLP is better than the previous method

# %% [markdown]
# ## Data Augmentation
#
# The reason why we are not getting good accuracy with MLP is because there is not a lot of data, only ~7000 training images, compared to the number of parameters in the MLP.
#
# Augmenting the training data with permutations  (e.g., scaling, rotating, skewing, flipping) is a good way to create more "data" for training the network.
# This can prevent the MLP from overfitting, and improve its generalization.  We will use the built-in `ImageDataGenerator` to apply geometric transformations.

# %% [markdown]
# We can also add per-pixel noise or transformations. We define a few functions for adding per-pixel noise.  The following functions will add Gaussian pixel noise, add corruption noise (setting some input pixels to 0), scale and shift pixel values (changing contrast and brightness).

# %%
def add_gauss_noise(X, sigma2=0.05):
    # add Gaussian noise with zero mean, and variance sigma2
    return X + random.normal(0, sigma2, X.shape)

def add_corrupt_noise(X, p=0.1):
    # apply pixel corruption (zero out value) with probability p
    return X * random.binomial(1, 1-p, X.shape)

def add_scale_shift(X, sigma2=0.1, alpha2=0.2):
    # randomly scale and shift the pixel values (same for each image)
    # Xnew = a X + b
    # a is sampled from a Gaussian with mean 1, and variance sigma2
    # b is sampled from a Gaussian with mean 0, and variance alpha2
    if X.ndim == 3:
        dshape = (X.shape[0],1,1)
    elif X.ndim == 4:
        dshape = (X.shape[0],1,1,1)
    else:
        dshape = (1,)
    a = random.normal(1,sigma2, dshape)
    b = random.normal(0,alpha2, dshape)
    return minimum(maximum( a*X + b, 0.0), 1.0)

# %% [markdown]
# Next, we define a function for adding per-pixel noise (in this case just Gaussian noise). The noise is included using the `preprocessing_function` input of the `ImageDataGenerator`.

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.05,     # image shifting
    height_shift_range=0.05,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

# %% [markdown]
# Next we can show some examples of augmented images. Run the code below to see different random augmentations.

# %%
img = trainI[4]
imgs = [img[:,:,0]]

cnt = 0
for augimg, augy in datagen.flow(img.reshape(1,19,19,1), [1], batch_size=1):
    imgs.append(augimg[0,:,:,0])
    cnt += 1
    if cnt > 4:
        # we need to break the loop by hand because
        # the generator loops indefinitely
        break

titles = ['original image', 'augmented', 'augmented', 'augmented', 'augmented', 'augmented']
plt.figure(figsize=(8,6))
show_imgs(imgs, nc=3, titles=titles)

# %% [markdown]
# The augmented images look similar to the original image, but contain small differences that the network can use to learn more about the class.

# %% [markdown]
# Now let's try training logistic regression with data augmentation. Instead sending the X,Y data to `fit`, we now  send it through the ImageDataGenerator first.  We disable early stopping so that the network sees more noisy data.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tf.random.set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_accuracy',             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(learning_rate=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit(
            datagen.flow(vtrainI, vtrainYb, batch_size=100),  # data from generator
            steps_per_epoch=len(vtrainI)/100,    # should be number of batches per epoch
            epochs=50,
            #callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)
# Out:
# Epoch 1/50
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2773 - accuracy: 0.8772 - val_loss: 0.1447 - val_accuracy: 0.9441
# Epoch 2/50
# 62/62 [==============================] - 1s 21ms/step - loss: 0.1743 - accuracy: 0.9285 - val_loss: 0.1388 - val_accuracy: 0.9413
# Epoch 3/50
# 62/62 [==============================] - 1s 22ms/step - loss: 0.1613 - accuracy: 0.9339 - val_loss: 0.1093 - val_accuracy: 0.9585
# Epoch 4/50
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1627 - accuracy: 0.9328 - val_loss: 0.1072 - val_accuracy: 0.9585
# Epoch 5/50
# 62/62 [==============================] - 2s 26ms/step - loss: 0.1574 - accuracy: 0.9374 - val_loss: 0.1437 - val_accuracy: 0.9427
# Epoch 6/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1569 - accuracy: 0.9406 - val_loss: 0.0996 - val_accuracy: 0.9599
# Epoch 7/50
# 62/62 [==============================] - 2s 35ms/step - loss: 0.1550 - accuracy: 0.9368 - val_loss: 0.0902 - val_accuracy: 0.9670
# Epoch 8/50
# 62/62 [==============================] - 2s 33ms/step - loss: 0.1499 - accuracy: 0.9395 - val_loss: 0.1022 - val_accuracy: 0.9542
# Epoch 9/50
# 62/62 [==============================] - 2s 33ms/step - loss: 0.1628 - accuracy: 0.9341 - val_loss: 0.1333 - val_accuracy: 0.9413
# Epoch 10/50
# 62/62 [==============================] - 2s 35ms/step - loss: 0.1522 - accuracy: 0.9396 - val_loss: 0.0934 - val_accuracy: 0.9685
# Epoch 11/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1568 - accuracy: 0.9350 - val_loss: 0.1101 - val_accuracy: 0.9556
# Epoch 12/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.1578 - accuracy: 0.9404 - val_loss: 0.1480 - val_accuracy: 0.9370
# Epoch 13/50
# 62/62 [==============================] - 3s 44ms/step - loss: 0.1513 - accuracy: 0.9401 - val_loss: 0.1145 - val_accuracy: 0.9542
# Epoch 14/50
# 62/62 [==============================] - 3s 46ms/step - loss: 0.1502 - accuracy: 0.9417 - val_loss: 0.1074 - val_accuracy: 0.9570
# Epoch 15/50
# 62/62 [==============================] - 3s 44ms/step - loss: 0.1550 - accuracy: 0.9401 - val_loss: 0.1313 - val_accuracy: 0.9413
# Epoch 16/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1464 - accuracy: 0.9427 - val_loss: 0.1044 - val_accuracy: 0.9599
# Epoch 17/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1487 - accuracy: 0.9412 - val_loss: 0.1029 - val_accuracy: 0.9599
# Epoch 18/50
# 62/62 [==============================] - 3s 45ms/step - loss: 0.1490 - accuracy: 0.9388 - val_loss: 0.1516 - val_accuracy: 0.9384
# Epoch 19/50
# 62/62 [==============================] - 3s 43ms/step - loss: 0.1429 - accuracy: 0.9436 - val_loss: 0.1009 - val_accuracy: 0.9542
# Epoch 20/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1518 - accuracy: 0.9428 - val_loss: 0.1480 - val_accuracy: 0.9355
# Epoch 21/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1496 - accuracy: 0.9403 - val_loss: 0.1252 - val_accuracy: 0.9398
# Epoch 22/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.1449 - accuracy: 0.9416 - val_loss: 0.1204 - val_accuracy: 0.9456
# Epoch 23/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.1489 - accuracy: 0.9409 - val_loss: 0.0985 - val_accuracy: 0.9585
# Epoch 24/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.1495 - accuracy: 0.9422 - val_loss: 0.1042 - val_accuracy: 0.9513
# Epoch 25/50
# 62/62 [==============================] - 3s 45ms/step - loss: 0.1520 - accuracy: 0.9411 - val_loss: 0.1277 - val_accuracy: 0.9398
# Epoch 26/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.1454 - accuracy: 0.9384 - val_loss: 0.1001 - val_accuracy: 0.9556
# Epoch 27/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.1570 - accuracy: 0.9382 - val_loss: 0.1039 - val_accuracy: 0.9556
# Epoch 28/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1530 - accuracy: 0.9376 - val_loss: 0.0997 - val_accuracy: 0.9628
# Epoch 29/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1483 - accuracy: 0.9449 - val_loss: 0.1181 - val_accuracy: 0.9484
# Epoch 30/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.1446 - accuracy: 0.9419 - val_loss: 0.1003 - val_accuracy: 0.9585
# Epoch 31/50
# 62/62 [==============================] - 3s 44ms/step - loss: 0.1389 - accuracy: 0.9447 - val_loss: 0.1150 - val_accuracy: 0.9542
# Epoch 32/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1500 - accuracy: 0.9435 - val_loss: 0.1093 - val_accuracy: 0.9570
# Epoch 33/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1496 - accuracy: 0.9382 - val_loss: 0.0904 - val_accuracy: 0.9585
# Epoch 34/50
# 62/62 [==============================] - 2s 35ms/step - loss: 0.1441 - accuracy: 0.9438 - val_loss: 0.0952 - val_accuracy: 0.9570
# Epoch 35/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1460 - accuracy: 0.9403 - val_loss: 0.1005 - val_accuracy: 0.9585
# Epoch 36/50
# 62/62 [==============================] - 2s 35ms/step - loss: 0.1470 - accuracy: 0.9384 - val_loss: 0.1097 - val_accuracy: 0.9527
# Epoch 37/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1462 - accuracy: 0.9427 - val_loss: 0.0968 - val_accuracy: 0.9613
# Epoch 38/50
# 62/62 [==============================] - 3s 42ms/step - loss: 0.1447 - accuracy: 0.9446 - val_loss: 0.1027 - val_accuracy: 0.9556
# Epoch 39/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1458 - accuracy: 0.9436 - val_loss: 0.1000 - val_accuracy: 0.9570
# Epoch 40/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1412 - accuracy: 0.9447 - val_loss: 0.1235 - val_accuracy: 0.9413
# Epoch 41/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1463 - accuracy: 0.9414 - val_loss: 0.1501 - val_accuracy: 0.9341
# Epoch 42/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1523 - accuracy: 0.9412 - val_loss: 0.0910 - val_accuracy: 0.9642
# Epoch 43/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1464 - accuracy: 0.9400 - val_loss: 0.1098 - val_accuracy: 0.9513
# Epoch 44/50
# 62/62 [==============================] - 3s 44ms/step - loss: 0.1397 - accuracy: 0.9468 - val_loss: 0.0937 - val_accuracy: 0.9656
# Epoch 45/50
# 62/62 [==============================] - 3s 42ms/step - loss: 0.1471 - accuracy: 0.9423 - val_loss: 0.1011 - val_accuracy: 0.9513
# Epoch 46/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1517 - accuracy: 0.9422 - val_loss: 0.1065 - val_accuracy: 0.9527
# Epoch 47/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.1470 - accuracy: 0.9435 - val_loss: 0.1320 - val_accuracy: 0.9327
# Epoch 48/50
# 62/62 [==============================] - 2s 35ms/step - loss: 0.1483 - accuracy: 0.9414 - val_loss: 0.0899 - val_accuracy: 0.9642
# Epoch 49/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.1468 - accuracy: 0.9466 - val_loss: 0.0972 - val_accuracy: 0.9585
# Epoch 50/50
# 62/62 [==============================] - 3s 43ms/step - loss: 0.1491 - accuracy: 0.9419 - val_loss: 0.1109 - val_accuracy: 0.9556

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.673728813559322

# %% [markdown]
# Using data augmentation, the test accuracy improves from 0.66 to 0.69!

# %% [markdown]
# Now train your best MLP from the previous section using data augmentation.
# Try different per-pixel noise levels, and different options of the ImageDataGenerator (see [here](https://keras.io/preprocessing/image/)),
# and combinations of them.  Hopefully you should be able to improve the accuracy!

# %%
### INSERT YOUR CODE HERE ###

# %%
def addNoise(X):
    return add_scale_shift(X)

datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')


img = trainI[4]
imgs = [img[:,:,0]]

cnt = 0
for augimg, augy in datagen.flow(img.reshape(1,19,19,1), [1], batch_size=1):
    imgs.append(augimg[0,:,:,0])
    cnt += 1
    if cnt > 4:
        # we need to break the loop by hand because
        # the generator loops indefinitely
        break

titles = ['original image', 'augmented', 'augmented', 'augmented', 'augmented', 'augmented']
plt.figure(figsize=(8,6))
show_imgs(imgs, nc=3, titles=titles)

K.clear_session()

nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))
nn.add(Dense(units=100,activation="sigmoid"))        # vectorize the input image
nn.add(Dense(units=20,activation="relu"))
nn.add(Dense(units=2, activation='softmax')) 

nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(learning_rate=0.02, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )
# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_accuracy',      # use validation accuracy for stopping
               min_delta=0.0005, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]


nn.summary()

history = nn.fit(
                 datagen.flow(vtrainI, vtrainYb, batch_size=100),
                 steps_per_epoch=len(vtrainI)/100, 
                 epochs=50,
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 361)               0
#
#  dense (Dense)               (None, 100)               36200
#
#  dense_1 (Dense)             (None, 20)                2020
#
#  dense_2 (Dense)             (None, 2)                 42
#
# =================================================================
# Total params: 38,262
# Trainable params: 38,262
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 62/62 [==============================] - 2s 27ms/step - loss: 0.5137 - accuracy: 0.7439 - val_loss: 0.2153 - val_accuracy: 0.9312
# Epoch 2/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.3666 - accuracy: 0.8374 - val_loss: 0.2006 - val_accuracy: 0.9198
# Epoch 3/50
# 62/62 [==============================] - 3s 42ms/step - loss: 0.3287 - accuracy: 0.8571 - val_loss: 0.2158 - val_accuracy: 0.9097
# Epoch 4/50
# 62/62 [==============================] - 3s 48ms/step - loss: 0.3291 - accuracy: 0.8554 - val_loss: 0.2180 - val_accuracy: 0.9069
# Epoch 5/50
# 62/62 [==============================] - 3s 43ms/step - loss: 0.3068 - accuracy: 0.8640 - val_loss: 0.1770 - val_accuracy: 0.9284
# Epoch 6/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.3066 - accuracy: 0.8707 - val_loss: 0.2131 - val_accuracy: 0.9112
# Epoch 6: early stopping
# test accuracy: 0.7817796610169492

# %%
def addNoise(X):
    return add_gauss_noise(X)

datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')


img = trainI[4]
imgs = [img[:,:,0]]

cnt = 0
for augimg, augy in datagen.flow(img.reshape(1,19,19,1), [1], batch_size=1):
    imgs.append(augimg[0,:,:,0])
    cnt += 1
    if cnt > 4:
        # we need to break the loop by hand because
        # the generator loops indefinitely
        break

titles = ['original image', 'augmented', 'augmented', 'augmented', 'augmented', 'augmented']
plt.figure(figsize=(8,6))
show_imgs(imgs, nc=3, titles=titles)

K.clear_session()

nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))
nn.add(Dense(units=100,activation="sigmoid"))        # vectorize the input image
nn.add(Dense(units=20,activation="relu"))
nn.add(Dense(units=2, activation='softmax')) 

nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(learning_rate=0.02, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )
# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_accuracy',      # use validation accuracy for stopping
               min_delta=0.0005, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]


nn.summary()

history = nn.fit(
                 datagen.flow(vtrainI, vtrainYb, batch_size=100),
                 steps_per_epoch=len(vtrainI)/100, 
                 epochs=50,
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 361)               0
#
#  dense (Dense)               (None, 100)               36200
#
#  dense_1 (Dense)             (None, 20)                2020
#
#  dense_2 (Dense)             (None, 2)                 42
#
# =================================================================
# Total params: 38,262
# Trainable params: 38,262
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 62/62 [==============================] - 2s 25ms/step - loss: 0.5110 - accuracy: 0.7347 - val_loss: 0.2536 - val_accuracy: 0.9054
# Epoch 2/50
# 62/62 [==============================] - 2s 32ms/step - loss: 0.3084 - accuracy: 0.8700 - val_loss: 0.1707 - val_accuracy: 0.9312
# Epoch 3/50
# 62/62 [==============================] - 3s 48ms/step - loss: 0.2782 - accuracy: 0.8812 - val_loss: 0.1713 - val_accuracy: 0.9312
# Epoch 4/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.2823 - accuracy: 0.8820 - val_loss: 0.1843 - val_accuracy: 0.9241
# Epoch 5/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.2607 - accuracy: 0.8920 - val_loss: 0.1792 - val_accuracy: 0.9255
# Epoch 6/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.2548 - accuracy: 0.8931 - val_loss: 0.2373 - val_accuracy: 0.8954
# Epoch 7/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.2498 - accuracy: 0.8962 - val_loss: 0.1357 - val_accuracy: 0.9513
# Epoch 8/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.2447 - accuracy: 0.9011 - val_loss: 0.2027 - val_accuracy: 0.9112
# Epoch 9/50
# 62/62 [==============================] - 3s 43ms/step - loss: 0.2203 - accuracy: 0.9116 - val_loss: 0.2494 - val_accuracy: 0.8954
# Epoch 10/50
# 62/62 [==============================] - 3s 43ms/step - loss: 0.2130 - accuracy: 0.9156 - val_loss: 0.1503 - val_accuracy: 0.9341
# Epoch 11/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.1928 - accuracy: 0.9251 - val_loss: 0.1322 - val_accuracy: 0.9441
# Epoch 12/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.1852 - accuracy: 0.9279 - val_loss: 0.1306 - val_accuracy: 0.9456
# Epoch 12: early stopping
# test accuracy: 0.8209745762711864

# %%
def addNoise(X):
    return add_corrupt_noise(X)

datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')


img = trainI[4]
imgs = [img[:,:,0]]

cnt = 0
for augimg, augy in datagen.flow(img.reshape(1,19,19,1), [1], batch_size=1):
    imgs.append(augimg[0,:,:,0])
    cnt += 1
    if cnt > 4:
        # we need to break the loop by hand because
        # the generator loops indefinitely
        break

titles = ['original image', 'augmented', 'augmented', 'augmented', 'augmented', 'augmented']
plt.figure(figsize=(8,6))
show_imgs(imgs, nc=3, titles=titles)

K.clear_session()

nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))
nn.add(Dense(units=100,activation="sigmoid"))        # vectorize the input image
nn.add(Dense(units=20,activation="relu"))
nn.add(Dense(units=2, activation='softmax')) 

nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(learning_rate=0.02, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )
# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_accuracy',      # use validation accuracy for stopping
               min_delta=0.0005, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]


nn.summary()

history = nn.fit(
                 datagen.flow(vtrainI, vtrainYb, batch_size=100),
                 steps_per_epoch=len(vtrainI)/100, 
                 epochs=50,
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 361)               0
#
#  dense (Dense)               (None, 100)               36200
#
#  dense_1 (Dense)             (None, 20)                2020
#
#  dense_2 (Dense)             (None, 2)                 42
#
# =================================================================
# Total params: 38,262
# Trainable params: 38,262
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 62/62 [==============================] - 2s 25ms/step - loss: 0.5063 - accuracy: 0.7516 - val_loss: 0.2508 - val_accuracy: 0.9011
# Epoch 2/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.3218 - accuracy: 0.8657 - val_loss: 0.2416 - val_accuracy: 0.8968
# Epoch 3/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.3018 - accuracy: 0.8710 - val_loss: 0.2897 - val_accuracy: 0.8782
# Epoch 4/50
# 62/62 [==============================] - 3s 42ms/step - loss: 0.2855 - accuracy: 0.8783 - val_loss: 0.1743 - val_accuracy: 0.9255
# Epoch 5/50
# 62/62 [==============================] - 3s 46ms/step - loss: 0.2807 - accuracy: 0.8837 - val_loss: 0.1725 - val_accuracy: 0.9312
# Epoch 6/50
# 62/62 [==============================] - 3s 43ms/step - loss: 0.2874 - accuracy: 0.8812 - val_loss: 0.2320 - val_accuracy: 0.9011
# Epoch 7/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.2743 - accuracy: 0.8850 - val_loss: 0.1756 - val_accuracy: 0.9269
# Epoch 8/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.2560 - accuracy: 0.8947 - val_loss: 0.1667 - val_accuracy: 0.9327
# Epoch 9/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.2623 - accuracy: 0.8898 - val_loss: 0.1867 - val_accuracy: 0.9226
# Epoch 10/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.2516 - accuracy: 0.8962 - val_loss: 0.1921 - val_accuracy: 0.9226
# Epoch 11/50
# 62/62 [==============================] - 3s 45ms/step - loss: 0.2326 - accuracy: 0.9032 - val_loss: 0.1417 - val_accuracy: 0.9341
# Epoch 12/50
# 62/62 [==============================] - 3s 44ms/step - loss: 0.2205 - accuracy: 0.9138 - val_loss: 0.1660 - val_accuracy: 0.9255
# Epoch 13/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.2160 - accuracy: 0.9086 - val_loss: 0.1744 - val_accuracy: 0.9226
# Epoch 14/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.2118 - accuracy: 0.9124 - val_loss: 0.1850 - val_accuracy: 0.9241
# Epoch 15/50
# 62/62 [==============================] - 3s 41ms/step - loss: 0.1956 - accuracy: 0.9212 - val_loss: 0.1575 - val_accuracy: 0.9284
# Epoch 16/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.2002 - accuracy: 0.9193 - val_loss: 0.1448 - val_accuracy: 0.9370
# Epoch 17/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.1993 - accuracy: 0.9193 - val_loss: 0.1486 - val_accuracy: 0.9370
# Epoch 18/50
# 62/62 [==============================] - 3s 42ms/step - loss: 0.1955 - accuracy: 0.9205 - val_loss: 0.1606 - val_accuracy: 0.9398
# Epoch 19/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1929 - accuracy: 0.9223 - val_loss: 0.1558 - val_accuracy: 0.9370
# Epoch 20/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1914 - accuracy: 0.9228 - val_loss: 0.1681 - val_accuracy: 0.9284
# Epoch 21/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1905 - accuracy: 0.9231 - val_loss: 0.1352 - val_accuracy: 0.9470
# Epoch 22/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.1881 - accuracy: 0.9287 - val_loss: 0.1414 - val_accuracy: 0.9441
# Epoch 23/50
# 62/62 [==============================] - 3s 39ms/step - loss: 0.1818 - accuracy: 0.9263 - val_loss: 0.1317 - val_accuracy: 0.9470
# Epoch 24/50
# 62/62 [==============================] - 3s 44ms/step - loss: 0.1753 - accuracy: 0.9330 - val_loss: 0.1874 - val_accuracy: 0.9241
# Epoch 25/50
# 62/62 [==============================] - 3s 42ms/step - loss: 0.1843 - accuracy: 0.9256 - val_loss: 0.1075 - val_accuracy: 0.9542
# Epoch 26/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1811 - accuracy: 0.9302 - val_loss: 0.1637 - val_accuracy: 0.9427
# Epoch 27/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1716 - accuracy: 0.9304 - val_loss: 0.1156 - val_accuracy: 0.9542
# Epoch 28/50
# 62/62 [==============================] - 2s 36ms/step - loss: 0.1779 - accuracy: 0.9283 - val_loss: 0.1174 - val_accuracy: 0.9570
# Epoch 29/50
# 62/62 [==============================] - 2s 37ms/step - loss: 0.1729 - accuracy: 0.9315 - val_loss: 0.1446 - val_accuracy: 0.9370
# Epoch 30/50
# 62/62 [==============================] - 3s 42ms/step - loss: 0.1744 - accuracy: 0.9279 - val_loss: 0.1446 - val_accuracy: 0.9484
# Epoch 31/50
# 62/62 [==============================] - 3s 43ms/step - loss: 0.1721 - accuracy: 0.9330 - val_loss: 0.1412 - val_accuracy: 0.9427
# Epoch 32/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.1660 - accuracy: 0.9347 - val_loss: 0.0985 - val_accuracy: 0.9585
# Epoch 33/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1635 - accuracy: 0.9385 - val_loss: 0.1229 - val_accuracy: 0.9527
# Epoch 34/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1561 - accuracy: 0.9384 - val_loss: 0.1049 - val_accuracy: 0.9599
# Epoch 35/50
# 62/62 [==============================] - 2s 39ms/step - loss: 0.1629 - accuracy: 0.9331 - val_loss: 0.1090 - val_accuracy: 0.9599
# Epoch 36/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1604 - accuracy: 0.9384 - val_loss: 0.2176 - val_accuracy: 0.9112
# Epoch 37/50
# 62/62 [==============================] - 3s 45ms/step - loss: 0.1628 - accuracy: 0.9352 - val_loss: 0.1006 - val_accuracy: 0.9585
# Epoch 38/50
# 62/62 [==============================] - 3s 40ms/step - loss: 0.1542 - accuracy: 0.9408 - val_loss: 0.1272 - val_accuracy: 0.9470
# Epoch 39/50
# 62/62 [==============================] - 2s 38ms/step - loss: 0.1558 - accuracy: 0.9406 - val_loss: 0.1247 - val_accuracy: 0.9484
# Epoch 39: early stopping
# test accuracy: 0.8845338983050848

# %% [markdown]
# _Which type of augmentation improves the accuracy the most?  Why?  How does NN with data augmentation compare with your work in Tutorial 4?_
#
# Adding the corrupted noise can improve the accuracy the most based on above experiments. The reason may be that the augmentated image make a large different with the original image without losing the important features. The performance of NN is better than the one in Tutorial 4

# %% [markdown]
# # Test image
# Now lets try your face detector on a real image.  Download the "nasa-small.png" image and put it in the same directory as your ipynb file.  The below code will load the image, crop out image patches and then extract features. (this may take a few minutes)

# %%
fname = "nasa-small.png"

# %%
# load image
testimg = skimage.io.imread(fname, as_gray=True)
print(testimg.shape)
plt.imshow(testimg, cmap='gray')
# Out:
# (210, 480)

# %%
# step size for the sliding window
step = 4

# extract window patches with step size of 4
patches = skimage.util.view_as_windows(testimg, (19,19), step=step)
psize = patches.shape
# collapse the first 2 dimensions
patches2 = patches.reshape((psize[0]*psize[1], psize[2], psize[3], 1))
print(patches2.shape)

# histogram equalize patches (improves contrast)
#newI = empty(patches2.shape)
#for i in range(patches2.shape[0]):
#    newI[i,:,:] = skimage.exposure.equalize_hist(patches2[i,:,:])
newI = patches2
# Out:
# (5568, 19, 19, 1)

# %% [markdown]
# Now predict using your classifier.  The extracted images are in `newI`.

# %%
### YOUR CODE HERE
prednewY = argmax(nn.predict(newI, verbose=False), axis=-1)

# %% [markdown]
# Now we we will view the results on the image.  Use the below code. `prednewY` is the vector of predictions.

# %%
# reshape prediction to an image
imgY = prednewY.reshape(psize[0], psize[1])

# zoom back to image size
imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# pad the top and left with half the window size
imgY2 = vstack((zeros((9, imgY2.shape[1])), imgY2))
imgY2 = hstack((zeros((imgY2.shape[0],9)), imgY2))
# pad right and bottom to same size as image
if (imgY2.shape[0] != testimg.shape[0]):
    imgY2 = vstack((imgY2, zeros((testimg.shape[0]-imgY2.shape[0], imgY2.shape[1]))))
if (imgY2.shape[1] != testimg.shape[1]):
    imgY2 = hstack((imgY2, zeros((imgY2.shape[0],testimg.shape[1]-imgY2.shape[1]))))
    
# show detections with image
#detimg = dstack(((0.5*imgY2+0.5)*testimg, 0.5*testimg, 0.5*testimg))
nimgY2 = 1-imgY2
tmp = nimgY2*testimg
detimg = dstack((imgY2+tmp, tmp, tmp))

# show it!
plt.figure(figsize=(9,9))
plt.subplot(2,1,1)
plt.imshow(imgY2, interpolation='nearest')
plt.title('detection map')
plt.subplot(2,1,2)
plt.imshow(detimg)
plt.title('image')
plt.axis('image')
# Out:
# C:\Users\jxian9\AppData\Local\Temp\ipykernel_13956\507828339.py:5: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# (-0.5, 479.5, 209.5, -0.5)

# %% [markdown]
# _How did your face detector do compared to the last version?_
#
# More points are laid on the face region when compared to last version

# %% [markdown]
# You can try it on your own images.  The faces should all be around 19x19 pixels though.
# We only used 1/8 of the training data. Try using more data to train it!
